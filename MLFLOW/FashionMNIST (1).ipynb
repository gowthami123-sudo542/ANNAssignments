# %%
"""## IMPORTING ALL NECESSARY LIBRARIES"""

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import mlflow
from  sklearn.metrics  import roc_auc_score

"""## LOADING THE DATASET"""

mnist=tf.keras.datasets.fashion_mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

print("The Shape of  the x_train dataset is",format(x_train.shape))
print("The Shape of the y_train dataset is ",y_train.shape)
print("The Shape of the x_test dataset is",x_test.shape)
print("The Shape of the x_test dataset is",y_test.shape)

"""## Scaling the dataset"""

x_valid,x_trains=x_train[:5000]/255.0,x_train[5000:]/255.0
y_valid,y_trains=y_train[:5000],y_train[5000:]
x_test=x_test/255.0

"""## CREATE A MODEL AND BUILD THE LAYERS"""

LAYERS=[tf.keras.layers.Flatten(input_shape=[28,28],name="InputLayer"),
        tf.keras.layers.Dense(300,activation="relu",name="HiddenLayer1"),
          tf.keras.layers.Dense(100,activation="relu",name="HiddenLayer2"),
        tf.keras.layers.Dense(10,activation="softmax",name="OutputLayer")]

model_clf=tf.keras.models.Sequential(LAYERS)

model_clf.summary()

## modelling the data
LOSS_FUNCTION="sparse_categorical_crossentropy"
OPTIMIZER="RMSProp"
METRICS=["accuracy"]
model_clf.compile(loss=LOSS_FUNCTION,optimizer=OPTIMIZER,metrics=METRICS)

## Using the  mlflow

mlflow.tensorflow.autolog()
with mlflow.start_run():
     model_clf.fit(x_trains,y_trains,epochs=40,validation_data=(x_valid,y_valid),batch_size=256)
     preds=model_clf.predict(x_test)
     preds=np.round(preds)
     eval_acc=model_clf.evaluate(x_test,y_test)[1]
     #auc_score=roc_auc_score(y_test,preds)
     print("eval_acc:",eval_acc)
     #print("auc_score:",auc_score)

# %% [markdown]
# ## BATCH NORMALIZATION

# %%
"""## IMPORTING ALL NECESSARY LIBRARIES"""
  
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import mlflow
from  sklearn.metrics  import roc_auc_score

"""## LOADING THE DATASET"""

mnist=tf.keras.datasets.fashion_mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

print("The Shape of  the x_train dataset is",format(x_train.shape))
print("The Shape of the y_train dataset is ",y_train.shape)
print("The Shape of the x_test dataset is",x_test.shape)
print("The Shape of the x_test dataset is",y_test.shape)

"""## Scaling the dataset"""

x_valid,x_trains=x_train[:5000]/255.0,x_train[5000:]/255.0
y_valid,y_trains=y_train[:5000],y_train[5000:]
x_test=x_test/255.0

"""## CREATE A MODEL AND BUILD THE LAYERS"""

LAYERS_BN=[
           tf.keras.layers.Flatten(input_shape=[28,28]),
           tf.keras.layers.BatchNormalization(),
           tf.keras.layers.Dense(300,activation="relu"),
           tf.keras.layers.BatchNormalization(),
           tf.keras.layers.Dense(100,activation="relu"),
           tf.keras.layers.BatchNormalization(),
           tf.keras.layers.Dense(10,activation="softmax")
]
model_clf=tf.keras.models.Sequential(LAYERS_BN)

model_clf.summary()

## modelling the data
LOSS_FUNCTION="sparse_categorical_crossentropy"
OPTIMIZER="RMSProp"
METRICS=["accuracy"]
model_clf.compile(loss=LOSS_FUNCTION,optimizer=OPTIMIZER,metrics=METRICS)

## Using the  mlflow

mlflow.tensorflow.autolog()
with mlflow.start_run():
     model_clf.fit(x_trains,y_trains,epochs=40,validation_data=(x_valid,y_valid),batch_size=256)
     preds=model_clf.predict(x_test)
     preds=np.round(preds)
     eval_acc=model_clf.evaluate(x_test,y_test)[1]
     #auc_score=roc_auc_score(y_test,preds)
     print("eval_acc:",eval_acc)
     #print("auc_score:",auc_score)
# Out:
# The Shape of  the x_train dataset is (60000, 28, 28)
# The Shape of the y_train dataset is  (60000,)
# The Shape of the x_test dataset is (10000, 28, 28)
# The Shape of the x_test dataset is (10000,)
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 271,346
# Trainable params: 268,978
# Non-trainable params: 2,368
# _________________________________________________________________
# Epoch 1/40
#   3/215 [..............................] - ETA: 3:15 - loss: 1.7717 - accuracy: 0.4505WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0164s vs `on_train_batch_end` time: 0.2998s). Check your callbacks.
# 215/215 [==============================] - 6s 24ms/step - loss: 0.4594 - accuracy: 0.8347 - val_loss: 0.3971 - val_accuracy: 0.8708
# Epoch 2/40
# 215/215 [==============================] - 3s 15ms/step - loss: 0.3240 - accuracy: 0.8804 - val_loss: 0.3287 - val_accuracy: 0.8752
# Epoch 3/40
# 215/215 [==============================] - 3s 16ms/step - loss: 0.2794 - accuracy: 0.8966 - val_loss: 0.3122 - val_accuracy: 0.8862
# Epoch 4/40
# 215/215 [==============================] - 4s 17ms/step - loss: 0.2512 - accuracy: 0.9058 - val_loss: 0.3090 - val_accuracy: 0.8816
# Epoch 5/40
# 215/215 [==============================] - 4s 20ms/step - loss: 0.2266 - accuracy: 0.9160 - val_loss: 0.3162 - val_accuracy: 0.8862
# Epoch 6/40
# 215/215 [==============================] - 4s 17ms/step - loss: 0.2071 - accuracy: 0.9239 - val_loss: 0.3200 - val_accuracy: 0.8852
# Epoch 7/40
# 215/215 [==============================] - 4s 17ms/step - loss: 0.1875 - accuracy: 0.9297 - val_loss: 0.3203 - val_accuracy: 0.8912
# Epoch 8/40
# 215/215 [==============================] - 3s 16ms/step - loss: 0.1721 - accuracy: 0.9371 - val_loss: 0.3239 - val_accuracy: 0.8930
# Epoch 9/40
# 215/215 [==============================] - 4s 17ms/step - loss: 0.1591 - accuracy: 0.9419 - val_loss: 0.3278 - val_accuracy: 0.8910
# Epoch 10/40
# 215/215 [==============================] - 4s 19ms/step - loss: 0.1465 - accuracy: 0.9468 - val_loss: 0.3194 - val_accuracy: 0.8976
# Epoch 11/40
# 215/215 [==============================] - 4s 17ms/step - loss: 0.1348 - accuracy: 0.9510 - val_loss: 0.3171 - val_accuracy: 0.9002
# Epoch 12/40
# 215/215 [==============================] - 3s 16ms/step - loss: 0.1249 - accuracy: 0.9538 - val_loss: 0.3334 - val_accuracy: 0.8942
# Epoch 13/40
# 215/215 [==============================] - 3s 16ms/step - loss: 0.1152 - accuracy: 0.9577 - val_loss: 0.3388 - val_accuracy: 0.8988
# Epoch 14/40
# 215/215 [==============================] - 3s 15ms/step - loss: 0.1072 - accuracy: 0.9610 - val_loss: 0.3534 - val_accuracy: 0.8960
# Epoch 15/40
40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.0378 - accuracy: 0.9863 - val_loss: 0.5587 - val_accuracy: 0.8926
# Epoch 36/40
# 215/215 [==============================] - 4s 19ms/step - loss: 0.0345 - accuracy: 0.9877 - val_loss: 0.5365 - val_accuracy: 0.8986
# Epoch 37/40
# 215/215 [==============================] - 4s 18ms/step - loss: 0.0342 - accuracy: 0.9877 - val_loss: 0.5683 - val_accuracy: 0.8928
# Epoch 38/40
# 215/215 [==============================] - 4s 16ms/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.5679 - val_accuracy: 0.8962
# Epoch 39/40
# 215/215 [==============================] - 4s 16ms/step - loss: 0.0311 - accuracy: 0.9893 - val_loss: 0.5891 - val_accuracy: 0.8984
# Epoch 40/40
# 215/215 [==============================] - 3s 16ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 0.5992 - val_accuracy: 0.9000
# 2022/06/16 21:52:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during tensorflow autologging: module 'keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6414 - accuracy: 0.8891
# eval_acc: 0.8891000151634216

# %% [markdown]
# ## Dropout

# %%
"""## IMPORTING ALL NECESSARY LIBRARIES"""
  
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import mlflow
from  sklearn.metrics  import roc_auc_score

"""## LOADING THE DATASET"""

mnist=tf.keras.datasets.fashion_mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

print("The Shape of  the x_train dataset is",format(x_train.shape))
print("The Shape of the y_train dataset is ",y_train.shape)
print("The Shape of the x_test dataset is",x_test.shape)
print("The Shape of the x_test dataset is",y_test.shape)

"""## Scaling the dataset"""

x_valid,x_trains=x_train[:5000]/255.0,x_train[5000:]/255.0
y_valid,y_trains=y_train[:5000],y_train[5000:]
x_test=x_test/255.0

"""## CREATE A MODEL AND BUILD THE LAYERS"""

LAYERS_BN=[
           tf.keras.layers.Flatten(input_shape=[28,28]),
           tf.keras.layers.Dropout(rate=0.5),
           tf.keras.layers.Dense(300,activation="relu"),
           tf.keras.layers.Dropout(rate=0.5),
           tf.keras.layers.Dense(100,activation="relu"),
           tf.keras.layers.Dropout(rate=0.5),
           tf.keras.layers.Dense(10,activation="softmax")
]
model_clf=tf.keras.models.Sequential(LAYERS_BN)

model_clf.summary()

## modelling the data
LOSS_FUNCTION="sparse_categorical_crossentropy"
OPTIMIZER="RMSProp"
METRICS=["accuracy"]
model_clf.compile(loss=LOSS_FUNCTION,optimizer=OPTIMIZER,metrics=METRICS)

## Using the  mlflow

mlflow.tensorflow.autolog()
with mlflow.start_run():
     model_clf.fit(x_trains,y_trains,epochs=40,validation_data=(x_valid,y_valid),batch_size=256)
     preds=model_clf.predict(x_test)
     preds=np.round(preds)
     eval_acc=model_clf.evaluate(x_test,y_test)[1]
     #auc_score=roc_auc_score(y_test,preds)
     print("eval_acc:",eval_acc)
     #print("auc_score:",auc_score)
# Out:
# The Shape of  the x_train dataset is (60000, 28, 28)
# The Shape of the y_train dataset is  (60000,)
# The Shape of the x_test dataset is (10000, 28, 28)
# The Shape of the x_test dataset is (10000,)
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
#   3/215 [..............................] - ETA: 26s - loss: 2.6061 - accuracy: 0.1393WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0160s vs `on_train_batch_end` time: 0.0365s). Check your callbacks.
# 215/215 [==============================] - 6s 22ms/step - loss: 1.0208 - accuracy: 0.6291 - val_loss: 0.5567 - val_accuracy: 0.7828
# Epoch 2/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.6824 - accuracy: 0.7522 - val_loss: 0.5110 - val_accuracy: 0.8240
# Epoch 3/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.6067 - accuracy: 0.7795 - val_loss: 0.4435 - val_accuracy: 0.8402
# Epoch 4/40
# 215/215 [==============================] - 4s 21ms/step - loss: 0.5727 - accuracy: 0.7959 - val_loss: 0.4268 - val_accuracy: 0.8484
# Epoch 5/40
# 215/215 [==============================] - 4s 20ms/step - loss: 0.5540 - accuracy: 0.8021 - val_loss: 0.4177 - val_accuracy: 0.8526
# Epoch 6/40
# 215/215 [==============================] - 5s 23ms/step - loss: 0.5376 - accuracy: 0.8052 - val_loss: 0.4061 - val_accuracy: 0.8556
# Epoch 7/40
# 215/215 [==============================] - 5s 23ms/step - loss: 0.5269 - accuracy: 0.8107 - val_loss: 0.4142 - val_accuracy: 0.8506
# Epoch 8/40
# 215/215 [==============================] - 5s 21ms/step - loss: 0.5206 - accuracy: 0.8147 - val_loss: 0.4140 - val_accuracy: 0.8568
# Epoch 9/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.5105 - accuracy: 0.8175 - val_loss: 0.3878 - val_accuracy: 0.86345106 - accuracy: 0.
# Epoch 10/40
# 215/215 [==============================] - 5s 23ms/step - loss: 0.5070 - accuracy: 0.8192 - val_loss: 0.3840 - val_accuracy: 0.8654s
# Epoch 11/40
# 215/215 [==============================] - 5s 23ms/step - loss: 0.5053 - accuracy: 0.8219 - val_loss: 0.3920 - val_accuracy: 0.8660
# Epoch 12/40
# 215/215 [==============================] - 5s 21ms/step - loss: 0.4956 - accuracy: 0.8252 - val_loss: 0.3821 - val_accuracy: 0.8674
# Epoch 13/40
# 215/215 [==============================] - 5s 21ms/step - loss: 0.4984 - accuracy: 0.8247 - val_loss: 0.3833 - val_accuracy: 0.8652
# Epoch 14/40
# 215/215 [==============================] - 5s 21ms/step - loss: 0.4905 - accuracy: 0.8266 - val_loss: 0.3807 - val_accuracy: 0.8678
# Epoch 15/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.4900 - accuracy: 0.8269 - val_loss: 0.3748 - val_accuracy: 0.8682
# Epoch 16/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.4861 - accuracy: 0.8295 - val_loss: 0.3819 - val_accuracy: 0.8668
# Epoch 17/40
# 215/215 [==============================] - 4s 21ms/step - loss: 0.4794 - accuracy: 0.8318 - val_loss: 0.3687 - val_accuracy: 0.8722
# Epoch 18/40
# 215/215 [==============================] - 5s 21ms/step - loss: 0.4803 - accuracy: 0.8301 - val_loss: 0.3770 - val_accuracy: 0.8674
# Epoch 19/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0.4769 - accuracy: 0.8331 - val_loss: 0.3759 - val_accuracy: 0.8708a
# Epoch 20/40
# 215/215 [==============================] - 5s 25ms/step - loss: 0.4787 - accuracy: 0.8314 - val_loss: 0.3693 - val_accuracy: 0.8738
# Epoch 21/40
# 215/215 [==============================] - 5s 22ms/step - loss: 0